# %%
from nilearn.plotting import view_img
from nilearn import datasets
from nilearn import plotting

# %% [markdown]
# # Fetch atlases

# %% [markdown]
# ## Schaefer atlas

# %%
atlas = datasets.fetch_atlas_schaefer_2018()
# Out:
# [get_dataset_dir] Dataset found in /root/nilearn_data/schaefer_2018

# %%
#plot a static map
plotting.plot_roi(atlas.maps)

# %%
#plot an interactive map
plotting.view_img(atlas.maps)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;background&quot;
#         /&gt;
#         &lt;!-- the colormap --&gt;
#         &lt;img
#           id=&quot;colorMap&quot;
# ...

# %% [markdown]
# ## Fetch and view three atlases of your choice from nilearn.datasets

# %% [markdown]
# You may select any 3 atlases from nilearn.datasets. Fetch and view the atlases using the above code as an example. Check out the documentation for `nilearn.plotting` at https://nilearn.github.io/stable/plotting/index.html to try different viewing methods, edit colours, change viewing options etc.

# %%
atlas1 = datasets.fetch_atlas_aal()
plotting.plot_roi(atlas1.maps)
# Out:
# [get_dataset_dir] Dataset found in /root/nilearn_data/aal_SPM12

# %%
plotting.view_img(atlas1.maps)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /usr/local/lib/python3.12/dist-packages/nilearn/image/resampling.py:805: UserWarning: Casting data from int32 to float32
#   return resample_img(
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
# ...

# %%
atlas2 = datasets.fetch_atlas_destrieux_2009()
plotting.plot_roi(atlas2.maps)
# Out:
# [get_dataset_dir] Dataset found in /root/nilearn_data/destrieux_2009

# %%
plotting.view_img(atlas2.maps)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /usr/local/lib/python3.12/dist-packages/nilearn/image/resampling.py:805: UserWarning: Casting data from int32 to float32
#   return resample_img(
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
# ...

# %%
atlas3 = datasets.fetch_atlas_schaefer_2018() # Couldn't find any other that worked out of the box :/
plotting.plot_roi(atlas3.maps)
# Out:
# [get_dataset_dir] Dataset found in /root/nilearn_data/schaefer_2018

# %%
plotting.view_img(atlas3.maps)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:868: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;background&quot;
#         /&gt;
#         &lt;!-- the colormap --&gt;
#         &lt;img
#           id=&quot;colorMap&quot;
# ...

# %% [markdown]
# # Compare and discuss

# %% [markdown]
# Compare the atlas parcellations and discuss your observations below. What might be some reasons that parcellation could affect your functional connectivity results?

# %%
# Differences between atlases
# Total brain coverage: The AAL atlas appears to have the most extensive coverage of the brain, the Destrieux atlas has the least.
# ROI granularity: The Destrieux atlas appears to have the most detailed ROIs, while the AAL atlas has the least.
# Number of ROIs: The Schaefer atlas has the most ROIs (by >2x as much), while the AAL atlas has the least.

# %%
# It seems that parcellation would affect functional connectivity results by being made up of different pre-defined brain regions
# (that may or may not be relevant -- or on the other hand -- fine-grained to the specific functional connectivity being studied).
